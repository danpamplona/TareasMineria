# %% [markdown]
# <a href="https://colab.research.google.com/github/danpamplona/TareasMineria/blob/main/Ejercicio_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejemplo mínimos cuadrados para regresión y su extensión no lineal
# ##Daniel E. Quintero Pamplona

# %% [markdown]
# [sklearn.linear model.LinearRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)
#
# Regresor lineal por mínimos cuadrados
#
# \begin{equation}
# \omega^* = \arg\min_\omega \|y-Xw\|^2_2
# \end{equation}

# %% [markdown]
# [sklearn.kernel ridge.KernelRidge](https://scikit-learn.org/stable/modules/generated/sklearn.kernel_ridge.KernelRidge.html)
#
# Regresor rígido kernel
#
#
#
# \begin{equation}
# \omega^* = \arg\min_\omega \|y-\Phi \omega\|^2_2 + \alpha\|\omega\|^2_2
# \end{equation}
#
# \begin{equation}
# \omega^* = (\Phi^\top \Phi+\alpha I)^{-1}\Phi^\top y
# \end{equation}
#
#
# \begin{equation}
# \omega^* = \Phi^\top(\Phi \Phi^\top+\alpha I)^{-1}y = k(\cdot)^\top(K+\alpha I)^{-1}y
# \end{equation}
#
# # Ejercicio 1
#
# - Presente la solución al problema de optimización kernel ridge (Ver [Kernel Ridge Regression](https://web2.qatar.cmu.edu/~gdicaro/10315-Fall19/additional/welling-notes-on-kernel-ridge.pdf))
#
# Dentro de$$\Phi = ?$$
#
# $$R = ?$$ $$P=?$$ factorizar para que quede $\alpha$
#
# ##Solución
# Se realizará un depeje matricial
# \begin{eqnarray*}
# (\Phi^\top \Phi+\alpha I)^{-1}\Phi^\top &=& (\alpha(\frac{1}{\alpha}\Phi^\top \Phi+ I))^{-1}\Phi^\top \\&=& \frac{1}{\alpha}(\frac{1}{\alpha}\Phi^\top \Phi+ I)^{-1}\Phi^\top \\&=& \frac{1}{\alpha}(\Phi^\top \frac{I}{\alpha} \Phi+ I)^{-1}\Phi^\top
# \end{eqnarray*}
#
# Ahora se compara con la ecuación del artículo:
#
# $(P^{-1}+B^\top R^{-1}B)^{-1}B^\top$
#
# Tenemos que:
# - $B = \Phi$
# - $R^{-1} = \frac{I}{\alpha}$
# - $P^{-1} = I$
#
# Y sustituyendo en la igualdad del artículo tenemos que:
# \begin{eqnarray}
# \frac{1}{\alpha}\Phi^\top(\Phi \frac{I}{\alpha} \Phi^\top+ I)^{-1} &=& \Phi^\top(\alpha(\Phi \frac{I}{\alpha} \Phi^\top+ I))^{-1} \\&=& \Phi^\top(\Phi\Phi^\top+ \alpha I))^{-1}
# \end{eqnarray}

# %% [markdown]
# ##**Ejemplo**
#
# - Se pretende generar un modelo de regresión bajo entradas con ruido blanco Gaussiano, con $\mu_\eta=0$, para seguir una función no lineal tipo sinc(x).
#
# - $y = {\rm{sinc}}(x)+\eta$;
# con $\eta\sim p(\eta)=\mathcal{N}(\eta|\mu_\eta,\sigma_\eta^2)=\frac{1}{\sqrt{2\pi\sigma^2_\eta}}\exp\left(\frac{-\|\eta-\mu_\eta\|_2^2}{2\sigma^2_\eta}\right)$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import warnings #eliminar warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")
N = 500 #número de muestras
X = np.linspace(-3*np.pi,3*np.pi,N) #vector de entrada 
y = np.sinc(X/np.pi) #función sinc -> objetivo
var = 0.1 #varianza del ruido
mue = 0 #media del ruido
noise = mue + np.sqrt(var)*np.random.randn(X.shape[0])#ruido blanco
yn = y + noise #señal co ruido
plt.plot(X,y,'r',label='target' )
plt.plot(X,yn,'k.',label='data')
plt.legend()
plt.show()

# %% [markdown]
# **Nota:** $${\rm{sinc}}(\theta)=\frac{\sin(\theta)}{\theta}$$
#
# - Se crean los vectores de entrada y salida tipo aprendizaje de máquina.

# %%
ydata = yn.reshape(-1,1)
Xdata = X.reshape(-1,1)
print(Xdata.shape) # N = 500 muestras, P = 1 atributos
print(ydata.shape) # N = 500, regresion univarida
# Out:
# (500, 1)
# (500, 1)

# %% [markdown]
# - Se entrenará un modelo de aprendizaje con scikitlearn

# %%
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score, cross_val_predict

X_train, X_test, y_train, y_test = train_test_split(Xdata, ydata,
                                                    test_size=0.3)#particionar train y test

print(X_train.shape)
print(X_test.shape)

plt.plot(X_train,y_train,'r.',label='train' )
plt.plot(X_test,y_test,'b.',label='test')
plt.legend()
plt.show()
# Out:
# (350, 1)
# (150, 1)

# %% [markdown]
# - Se utilizará el modelo [KernelRidge](https://scikit-learn.org/stable/modules/generated/sklearn.kernel_ridge.KernelRidge.html) con función kernel tipo radial basis function (rbf):
#
#
# $$\kappa(x,x') = \exp\left(\frac{-\gamma\|x-x'\|^2_2}{2}\right)$$
#
# **Nota:** el hiperparámetro $\gamma\in\mathbb{R}^+$ se conoce como precisión y pretende escalar la noción de parecido entre los puntos. La precisión se relaciona comunmente con el parámetro ancho de banda ("varianza") $\sigma\in\mathbb{R}^+$ del modelo rbf, según:
#
# $$\gamma=\frac{1}{\sigma^2}$$

# %%
from sklearn.linear_model import LinearRegression
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import Pipeline
gamma = 0.1 #gamma
alpha = 0.001 # valor de regularización
reg = KernelRidge(kernel='rbf',gamma=gamma, alpha = alpha)
reg.fit(X_train,y_train) #ajustar solo sobre train
#prediccion
y_test_e = reg.predict(X_test)
y_train_e = reg.predict(X_train)

plt.plot(X_test,y_test,'r.',label='y_test' )
plt.plot(X_test,y_test_e,'k.',label='y_test_e')
plt.legend()
plt.show()

# %% [markdown]
# - Es  necesario encontar unos buenos hiperparámetros para seguir la función no lineal

# %%
steps=[('reg', KernelRidge(kernel = 'rbf'))]
parameters = {'reg__alpha' : [0,1e-3,1e-2,0.1,1,10,100,1000],              
              'reg__gamma': [1e-4,1e-3,1e-2,0.1,1,10,100,1000],
              }

pipeline = Pipeline(steps = steps)

grid_search = GridSearchCV(pipeline, parameters, n_jobs=4,cv=10,
                           scoring='neg_mean_absolute_error',verbose=10,refit=True)

grid_search.fit(X_train, y_train)
#mejor modelo entrenado
best_model = grid_search.best_estimator_

print("\nMejores parámetros:\n")
print(grid_search.best_params_)
# Out:
# Fitting 10 folds for each of 64 candidates, totalling 640 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1870s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1854s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 100 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=4)]: Done 144 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=4)]: Done 196 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 248 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=4)]: Done 308 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=4)]: Done 368 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=4)]: Done 436 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=4)]: Done 580 tasks      | elapsed:    7.2s
# Mejores parámetros:
#
# {'reg__alpha': 1, 'reg__gamma': 0.1}
# [Parallel(n_jobs=4)]: Done 640 out of 640 | elapsed:    7.6s finished

# %% [markdown]
# - Se evaluan los datos de test y train con el mejor modelo encontrado

# %%
y_test_e = grid_search.best_estimator_.predict(X_test)
y_train_e = grid_search.best_estimator_.predict(X_train)
plt.plot(X_train,y_train_e,'r.',label='ytraine' )
plt.plot(X_test,y_test_e,'b.',label='yteste')
plt.plot(X,y,'k',label='target' )
plt.plot(Xdata,ydata,'g.',label='data' )
plt.legend()
plt.show()

# %% [markdown]
# - Visualicemos la función kernel:

# %%
from sklearn.metrics import pairwise_distances as dist

D = dist(X.reshape(-1,1),X.reshape(-1,1)) #disimilitud
gamma = 100
K = np.exp(-.5*gamma*D**2)
D.shape
plt.imshow(D)
plt.colorbar()
plt.show()


plt.imshow(K)
plt.colorbar()
plt.show()

# %% [markdown]
# Recuerde que:
#
# \begin{equation}
# \kappa(x,x') = \frac{1}{\sqrt{2\pi \sigma^2}}\exp\left(\frac{-\|x-x'\|_2^2}{2\sigma^2}\right) = \frac{1}{\sqrt{2\pi \sigma^2}}\exp\left(\frac{-\gamma\|x-x'\|_2^2}{2}\right)
# \end{equation}

# %% [markdown]
# #Ejercicio 2
#
# - Visualice el kernel rbf para diferentes condiciones de ruido sintonizando los hiperparámetros del modelo utilizando gridsearch.
#
# - Realice una descomposición en valores propios de la matriz kernel para cada una de las condiciones de ruido del punto anterior, qué puede discutir sobre el espectro de la matríz y su influencia en el modelo predictivo de kernel ridge?. Cuál es la relación entre el espectro visualizado y el hiperparámetro de regularización o penalidad encontrado por gridsearch en cada caso?.
# ##Solución

# %%
import numpy as np
import matplotlib.pyplot as plt
VarN_1 = [0.010, 0.1, 1]
MeanN_1 = [0.0, 0.0, 0.0]
N_1 = 500 #número de muestras
yn_1 = np.zeros((len(VarN_1),N_1))
X_1 = np.linspace(-3*np.pi,3*np.pi,N_1) #vector de entrada 
y_1 = np.sinc(X_1/np.pi) #función sinc -> objetivo


for i in range(len(VarN_1)):
  var_1 = VarN_1[i] #varianza del ruido
  mue_1 = MeanN_1[i] #media del ruido
  noise_1 = mue_1 + np.sqrt(var_1)*np.random.randn(X_1.shape[0])#ruido blanco
  yn_1[i] = y_1 + noise_1 #señal co ruido
  plt.plot(X_1,y_1,'r',label='target' )
  plt.plot(X_1,yn_1[i],'k.',label='data')
  plt.title('Varianza = ' +str(VarN_1[i]), size = 11)
  plt.legend()
  plt.show()

# %%
Xdata = X.reshape(-1,1) #N=500, P= 1
y = y.reshape(-1,1)
ydata = yn.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(Xdata, ydata,
                                                    test_size=0.3)#particionar train y test

# %%
steps=[('reg', KernelRidge(kernel = 'rbf'))]
parameters = {'reg__alpha' : [0,1e-3,1e-2,0.1,1,10,100,1000],              
              'reg__gamma': [1e-4,1e-3,1e-2,0.1,1,10,100,1000],
              }

pipeline = Pipeline(steps = steps)

grid_search = GridSearchCV(pipeline, parameters, n_jobs=4,cv=10,
                           scoring='neg_mean_absolute_error',verbose=10,refit=True)

grid_search.fit(X_train, y_train)
#mejor modelo entrenado
best_model = grid_search.best_estimator_

print("\nMejores parámetros:\n")
print(grid_search.best_params_)
# Out:
# Fitting 10 folds for each of 64 candidates, totalling 640 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1321s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1996s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done 100 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1453s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Done 160 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 264 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=4)]: Done 368 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=4)]: Done 488 tasks      | elapsed:    4.6s
# Mejores parámetros:
#
# {'reg__alpha': 0.001, 'reg__gamma': 0.1}
# [Parallel(n_jobs=4)]: Done 640 out of 640 | elapsed:    5.6s finished

# %%
ytest_e = grid_search.best_estimator_.predict(X_test)

plt.plot(X,y,'b',label='target' )
plt.plot(X,yn,'k.',label='data' )
plt.plot(X_test,ytest_e,'r.',label='ytest_e')
plt.legend()
plt.show()

# %%
D = dist(X.reshape(-1,1),X.reshape(-1,1)) #disimilitud
gamma = 0.1
alpha = 10
K = np.exp(-.5*gamma*D**2)
Kalpha = K + alpha*np.eye(N)

val,vec = np.linalg.eig(K)
val_a,vec_a = np.linalg.eig(Kalpha)

D.shape
plt.imshow(D)
plt.colorbar()
plt.show()


plt.imshow(K)
plt.colorbar()
plt.show()

# %% [markdown]
# Al hacer algunos cambios de la varianza se aprecia que el gamma estimado, que depende de la varianza, en las diferentes gráficas el cuando este gamma varía en cada una de las gráficas esta dispersión afecta el modelo y por esola banda se encoge o se amplía

# %%
plt.stem(val)
plt.show()

plt.stem(val_a)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# Ahora vamos a generalizar los resultados anteriores dentro de ciclos for.

# %%
# Sintonización de hiperparámetros
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score, cross_val_predict
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import Pipeline

pipeline = Pipeline(steps = steps)

grid_search = GridSearchCV(pipeline, parameters, n_jobs=4,cv=10,
                           scoring='neg_mean_absolute_error',verbose=10,refit=True)

g = []
a = []
for i in range(len(VarN_1)):
  grid_search.fit(X_1.reshape(-1,1), yn_1[i].reshape(-1,1))
  #mejor modelo entrenado
  best_model = grid_search.best_estimator_
  g.append(grid_search.best_params_['reg__gamma'])
  a.append(grid_search.best_params_['reg__alpha'])
  print("\nMejores parámetros:\n")
  print(grid_search.best_params_)
# Out:
# Fitting 10 folds for each of 64 candidates, totalling 640 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1702s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=4)]: Done  98 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=4)]: Done 146 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1969s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done 172 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 220 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=4)]: Done 348 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=4)]: Done 416 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 492 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=4)]: Done 568 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=4)]: Done 633 out of 640 | elapsed:    9.9s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 640 out of 640 | elapsed:    9.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Mejores parámetros:
#
# {'reg__alpha': 1, 'reg__gamma': 0.1}
# Fitting 10 folds for each of 64 candidates, totalling 640 fits
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1700s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=4)]: Done  98 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1934s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=4)]: Done 172 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 224 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=4)]: Done 284 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=4)]: Done 344 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=4)]: Done 412 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 480 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=4)]: Done 556 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=4)]: Done 626 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=4)]: Done 633 out of 640 | elapsed:    9.9s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 640 out of 640 | elapsed:    9.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Mejores parámetros:
#
# {'reg__alpha': 1, 'reg__gamma': 0.1}
# Fitting 10 folds for each of 64 candidates, totalling 640 fits
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1715s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done  98 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1991s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=4)]: Done 172 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=4)]: Done 224 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=4)]: Done 284 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=4)]: Done 344 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=4)]: Done 412 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=4)]: Done 480 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=4)]: Done 556 tasks      | elapsed:    8.8s
# Mejores parámetros:
#
# {'reg__alpha': 1, 'reg__gamma': 0.1}
# [Parallel(n_jobs=4)]: Done 629 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=4)]: Done 640 out of 640 | elapsed:    9.8s finished

# %%
# Visualización del Kernel
from sklearn.metrics import pairwise_distances as dist
D = dist(X_1.reshape(-1,1),X_1.reshape(-1,1)) #disimilitud
plt.imshow(D)
plt.colorbar()
plt.show()
for i in g:
  gamma = i
  K = np.exp(-.5*gamma*D**2)
  plt.imshow(K)
  plt.colorbar()
  plt.title('Gamma = '+str(i), size = 11)
  plt.show()

# %%
for i in range(len(g)):
  gamma = g[i]
  alpha = a[i]
  K = np.exp(-.5*gamma*D**2)
  Kalpha = K + alpha*np.eye(N_1)

  val,vec = np.linalg.eig(K)
  val_a,vec_a = np.linalg.eig(Kalpha)

  plt.imshow(K)
  plt.colorbar()
  plt.title('Gamma = '+str(g[i])+'Alpha = '+str(a[i]), size=10)
  plt.show()
  
  plt.stem(val)
  plt.show()

  plt.stem(val_a)
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
ytest_e = grid_search.best_estimator_.predict(X_test)

plt.plot(X,y,'b',label='target' )
plt.plot(X,yn,'k.',label='data' )
plt.plot(X_test,ytest_e,'r.',label='ytest_e')
plt.legend()
plt.show()

# %%
from sklearn.metrics import pairwise_distances as dist

D_1 = dist(X_1.reshape(-1,1),X_1.reshape(-1,1)) #disimilitud
gamma_1 = 0.1
K_1 = np.exp(-.5*gamma_1*D_1**2)
D_1.shape
plt.imshow(D_1)
plt.colorbar()
plt.show()


plt.imshow(K_1)
plt.colorbar()
plt.show()
